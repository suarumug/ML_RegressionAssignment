# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
#split training set

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
# LG model creation 
import lightgbm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # LG model creation
# ----> 2 import lightgbm
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
# !pip install lightgbm
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 355.3 kB/s eta 0:00:03
#    -------------- ------------------------- 0.5/1.5 MB 355.3 kB/s eta 0:00:03
#    -------------- ------------------------- 0.5/1.5 MB 355.3 kB/s eta 0:00:03
#    -------------- ------------------------- 0.5/1.5 MB 355.3 kB/s eta 0:00:03
#    --------------------- ------------------ 0.8/1.5 MB 375.2 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.0/1.5 MB 450.4 kB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 450.4 kB/s eta 0:00:01
# ...

# %%
import lightgbm

# %%
from lightgbm import LGBMRegressor
regressor=LGBMRegressor(n_estimators=150,max_depth=2,random_state=0,force_col_wise=True)
regressor.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Total Bins 313
# [LightGBM] [Info] Number of data points in the train set: 936, number of used features: 5
# [LightGBM] [Info] Start training from score 13232.916456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
y_predict=regressor.predict(x_test)

# %%
# r2score evaluation 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_predict)

# %%
r_score
# Out:
# 0.8910925564028029

# %%
import pickle
filename="LGBoosting Algorithm.sav"

# %%
pickle.dump(regressor,open(filename,"wb"))

# %%
load_model=pickle.load(open("LGBoosting Algorithm.sav","rb"))

# %%
result=load_model.predict([[34,23,5,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([22632.59550571])
