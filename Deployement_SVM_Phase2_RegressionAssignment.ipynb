# %%
import pickle

# %%
load_model=pickle.load(open("RegressionAssignmentSVM.sav","rb"))

# %%
result=load_model.predict([[25,33,2,0,0]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([4177.77222065])
